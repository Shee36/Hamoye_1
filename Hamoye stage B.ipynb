# %%
# importing the required library
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 12))
import seaborn as sns
sns.set(color_codes=True)

# %%
energy_data = pd.read_csv(r'file:///C:\Users\misso\Downloads\energydata_complete.csv')
energy_data.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
energy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
energy_data.describe(include="all")
# Out:
#                        date    Appliances        lights            T1  \
# count                 19735  19735.000000  19735.000000  19735.000000
# unique                19735           NaN           NaN           NaN
# top     2016-01-17 02:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN     97.694958      3.801875     21.686571
# std                     NaN    102.524891      7.935988      1.606066
# min                     NaN     10.000000      0.000000     16.790000
# 25%                     NaN     50.000000      0.000000     20.760000
# 50%                     NaN     60.000000      0.000000     21.600000
# 75%                     NaN    100.000000      0.000000     22.600000
# max                     NaN   1080.000000     70.000000     26.260000
#
#                 RH_1            T2          RH_2            T3          RH_3  \
# ...

# %%
# checking for duplicate rows
energy_data.duplicated().any()
# Out:
# False

# %%
# checking for duplicate rows
energy_data.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
Feature_energy = energy_data.drop(columns=["date", "lights"], axis=1)
Feature_energy
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
Target_energy = Feature_energy[["Appliances"]]
Target_energy
# Out:
#        Appliances
# 0              60
# 1              60
# 2              50
# 3              50
# 4              60
# ...           ...
# 19730         100
# 19731          90
# 19732         270
# 19733         420
# 19734         430
#
# [19735 rows x 1 columns]

# %%
# select a sample of the dataset

sample_feature_energy = Feature_energy[["RH_3", "Appliances"]].sample(15, random_state=42)
sns.regplot(x="RH_3", y="Appliances", data=Feature_energy)
# Out:
# <AxesSubplot:xlabel='RH_3', ylabel='Appliances'>

# %%
# lets normalise the dataset to a common scale using the minmax scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_energy = pd.DataFrame(scaler.fit_transform(Feature_energy), columns=Feature_energy.columns)
feature_energy = normalized_energy.drop(columns=["Appliances"])
appliances_target = normalized_energy["Appliances"]

# we now split our data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feature_energy, appliances_target, test_size=0.3, random_state=42)

# lets perform a regression model on the dataset
from sklearn.linear_model import LinearRegression
# we instantiate the linear regression
linear_reg = LinearRegression()
# we fit the model to a training dataset
linear_reg.fit(X_train, y_train)
# lets obtain the prediction
predicted_reg = linear_reg.predict(X_test)

# %%
# mean absolute error
from sklearn.metrics import mean_absolute_error
mae_reg = mean_absolute_error(y_test, predicted_reg)
round(mae_reg, 2)
# Out:
# 0.05

# %%
# residual sum of squares (RSS)
import numpy as np
rss_reg = np.sum(np.square(y_test - predicted_reg))
round(rss_reg, 2)
# Out:
# 45.35

# %%
# Root Mean Square Error (RMSE)
from sklearn.metrics import mean_squared_error
rmse_reg = np.sqrt(mean_squared_error(y_test, predicted_reg))
round(rmse_reg, 3)
# Out:
# 0.088

# %%
# R-Squared
from sklearn.metrics import r2_score
r2_reg = r2_score(y_test, predicted_reg)
round(r2_reg, 2)
# Out:
# 0.15

# %%
# Using Ridge
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.5)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
# Using Lasso
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.001)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
# Comparing the effect of both regularization
def get_weight_df1(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df1 = pd.DataFrame(weights).reset_index()
    weights_df1.columns = ["Features", col_name]
    weights_df1[col_name].round(3)
    return weights_df1

linear_models_weights = get_weight_df1(linear_reg, X_train, "Linear_Model_Weight")
ridge_weight_df1 = get_weight_df1(ridge, X_train, "Ridge_Weight")
lasso_weight_df1 = get_weight_df1(lasso, X_train, "Lasso_Weight")

final_weights = pd.merge(linear_models_weights, ridge_weight_df1, on="Features")
final_weights = pd.merge(final_weights, lasso_weight_df1, on="Features")
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0          RH_2            -0.456698     -0.401134     -0.000000
# 1         T_out            -0.321860     -0.250765      0.000000
# 2            T2            -0.236178     -0.193880      0.000000
# 3            T9            -0.189941     -0.188584     -0.000000
# 4          RH_8            -0.157595     -0.156596     -0.000110
# 5        RH_out            -0.077671     -0.050541     -0.049557
# 6          RH_7            -0.044614     -0.046291     -0.000000
# 7          RH_9            -0.039800     -0.041701     -0.000000
# 8            T5            -0.015657     -0.020727     -0.000000
# 9            T1            -0.003281     -0.021549      0.000000
# 10          rv1             0.000770      0.000743     -0.000000
# 11          rv2             0.000770      0.000743     -0.000000
# 12  Press_mm_hg             0.006839      0.006516     -0.000000
# ...

# %%
energy = energy_data.drop(['date', 'lights'], axis = 1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalized_df = pd.DataFrame(scaler.fit_transform(energy), columns = energy.columns)

# %%
normalized_df.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
X = normalized_df.drop(['Appliances'], axis = 1)
y = normalized_df['Appliances']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
x1 = np.array(normalized_df['T2'])
y1 = np.array(normalized_df['T6'])
#we need to reshape the x variable because we have only one predictor here
x1 = x1.reshape(-1, 1)
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.3, random_state = 42)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x1_train, y1_train)
y1_pred = model.predict(x1_test)

from sklearn.metrics import r2_score
r2 = r2_score(y1_test, y1_pred)
round(r2, 2)
# Out:
# 0.64

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
train_score = reg.score(X_train, y_train)
test_score = reg.score(X_test, y_test)
print("{:.3f}".format(train_score))
print("{:.3f}".format(test_score))
# Out:
# 0.145
# 0.149

# %%
# Mean Absolute Error(MAE)

from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('MAE for linear model: {}'.format(round(mae, 2)))
# Out:
# MAE for linear model: 0.05

# %%
# Residual Sum of Squares(RSS)

rss = np.sum(np.square(y_test - y_pred))
print('RSS for linear model: {}'.format(round(rss, 2)))
# Out:
# RSS for linear model: 45.35

# %%
# Root Mean Squared Error(RMSE)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print('RMSE for linear model: {}'.format(round(rmse, 3)))
# Out:
# RMSE for linear model: 0.088

# %%
# R_Squared (coefficient of determination)

from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_pred)
print('R_Squared for linear model: {}'.format(round(r_squared, 2)))
# Out:
# R_Squared for linear model: 0.15

# %%
def weights(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

linear_reg_weights = weights(reg, X_train, 'Linear_model_Weight')
linear_reg_weights
# Out:
#        Features  Linear_model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha = 0.4)
ridge.fit(X_train, y_train)
ridge_pred = ridge.predict(X_test)
train_score = ridge.score(X_train, y_train)
test_score = ridge.score(X_test, y_test)
print("Training score of ridge regression model is {:.3f}".format(train_score))
print("Testing score of ridge regression model is {:.3f}".format(test_score))
# Out:
# Training score of ridge regression model is 0.145
# Testing score of ridge regression model is 0.149

# %%
# Root Mean Squared Error(RMSE) for ridge model

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, ridge_pred)
rmse = np.sqrt(mse)
print('RMSE for ridge model: {}'.format(round(rmse, 3)))
# Out:
# RMSE for ridge model: 0.088

# %%
# lasso model at alpha = 0.001

from sklearn.linear_model import Lasso
lasso0001 = Lasso(alpha = 0.001)
lasso0001.fit(X_train, y_train)
lasso0001_pred = lasso0001.predict(X_test)
train_score = lasso0001.score(X_train, y_train)
test_score = lasso0001.score(X_test, y_test)
print("Training score is {:.3f}".format(train_score))
print("Testing score is {:.3f}".format(test_score))
print("Number of features for training: {:.3f}".format(np.sum(lasso0001.coef_ != 0)))
# Out:
# Training score is 0.025
# Testing score is 0.027
# Number of features for training: 4.000

# %%
# Root Mean Squared Error(RMSE) for lasso model

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, lasso0001_pred)
rmse = np.sqrt(mse)
print('{}'.format(round(rmse, 3)))
# Out:
# 0.094
